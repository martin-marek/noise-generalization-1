# %%
# %%capture
! pip install fire wandb

# %%
import os
from google.colab import userdata
os.chdir('/content/drive/MyDrive/Research/noise-3')
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
os.environ['WANDB_SILENT'] = 'true'

# %%
! python train.py --peak_lr=0.0001 --n_epochs=10 --wandb_mode='online'
# Out:
# n_params=273_258
# 100% 10/10 [00:11<00:00,  1.11s/it, train_acc=81.9%, val_acc=80.5%]

# %%
import importlib
import train
importlib.reload(train)

model_name =
train.train(model_name='resnset110', peak_lr=1e-1, n_epochs=100, run_name=f'resnset110_{lr=}', wandb_mode='online')
# Out:
# n_params=1_972_792
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
for n_layers in [20, 32, 44, 56, 110]:
    model_name = f'resnet{n_layers}'
    for lr in [1e-4, 1e-3, 1e-2, 1e-1]:
        train.train(model_name=model_name, peak_lr=lr, n_epochs=100, run_name=f'{model_name}_{lr=}', wandb_mode='online')
# Out:
# n_params=273_258
#   0%|          | 0/100 [00:00<?, ?it/s]
# n_params=273_258
#   0%|          | 0/100 [00:00<?, ?it/s]
# n_params=273_258
#   0%|          | 0/100 [00:00<?, ?it/s]
# n_params=273_258
#   0%|          | 0/100 [00:00<?, ?it/s]
# n_params=468_138
#   0%|          | 0/100 [00:00<?, ?it/s]
# n_params=468_138
#   0%|          | 0/100 [00:00<?, ?it/s]
